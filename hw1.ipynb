# %% [markdown]
# # Homework XX
#
# ## Exercise YY
#
# ### Answers:
# Fill in your anwers here so André can do a quick check if they are right/wrong:
#
# * **Example, please erase before handing in**: The probability of ..... is $\frac{p}{2-p}$
# * ...
# * ...
#
#
# ### Solution:
#
# An example of how to write an equation:
# $$
#     x = y + \alpha \cdot \sum_{i=0}^{27} \left(i^4 + 7 \right)^{544} + \frac{\partial f}{\partial x_1} + \cdots
# $$
#
# Remember that markdown accepts most latex/tex notation for the math.
#
# An example of a probability
# $$
#     \Pr[X = k] = {n \choose k} p^k (1-p)^{n-k}, \quad \forall k \in \{i \in \mathbb{N}: 0 \leq i \leq n \}
# $$
# For this variable the expectaion and variance is:
# $$
#     \text{E}[X] = np
# $$
# and
# $$
#     \text{Var}[X] = n p (1-p)
# $$

# %%
# Placeholder for python part of exercise YY

# %% [markdown]
# ## Exercise ZZ
#
# ### Answers:
# Fill in your answers here so André can do a quick check if they are right/wrong
#
# * ...
# * ...
# * ...
#
# ### Solution:

# %%
# Placeholder for python part of exercise ZZ
