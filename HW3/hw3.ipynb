# %% [markdown]
# # Homework 3
#
# ## Exercise 34 (Errors in these notes)
# Let $X$ be a Poisson random variable
# with mean $\mu$ representing the number of errors on a page of these notes. Each
# error is independently a grammatical error with probability $p$ or a spelling error
# with probability $1−p$. If $Y$ and $Z$ are random variables representing the number
# of grammatical and spelling errors on a page of this book, prove that $Y$ and $Z$
# are Poisson random variables with means $\mu p$ and $\mu (1 −p)$, respectively. Also
# prove that $Y$ and $Z$ are independent.
# ### Answers:
#
# *
# *
# *
#
#
# ### Solution:

# %% [markdown]
# ## Python
# Generate $X, Y, Z$ according to the desciption above with $\mu = 10$ and $p=0.3$. Generate $10^4$ instances and verify that what you've proven holds.

# %%
# Placeholder for python part of exercise YY

# %% [markdown]
# ## Exercise 38 (Game board)
# A circular game board has $K$ spaces numbered
# $0,1,\ldots K −1$. Starting at space $0$ at time $n = 0$, a player rolls a fair six-sided
# die to move a token.
#
# Hence, given the current token position $X_n$, the next token
# position is $X_{n+1} = (X_n + R_n) \mod K$ where $R_n$ is the result of the player’s
# $n \text{th}$ roll. Find the stationary probability vector.
# ### Answers:
#
#
# *
# *
# *
#
# ### Solution:

# %% [markdown]
# ## Python
# Fix $K > 20$ and initialise $2K$ different state probability vectors
# $p_i(0)$, $i \in\{0,\cdots ,2K −1\}$. Calculate $p_i(10^3), i \in\{0,\cdots ,2K −1\}$ and see if it
# is close to the stationary probability vector. Plot your results.

# %%
# Placeholder for python part of exercise ZZ
